# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
from math import sqrt

print(
    *filter(
        lambda x:
        all(
            map(
                lambda y:
                x % y != 0,
                range(
                    2, int(sqrt(x)) + 1
                )
            )
        ),
        range(
            2, int(input()) + 1
        )
    )
)
